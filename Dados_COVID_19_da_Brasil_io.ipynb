# %% [markdown]
# <a href="https://colab.research.google.com/github/dhonysilva/covid-2019/blob/master/Dados_COVID_19_da_Brasil_io.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Utlização dos dados consolidados e disponibilizados pelo coletivo [Brasil.io](https://brasil.io/dataset/covid19/caso)
#
# Os dados contêm os Boletins Informativos de casos do coronavírus por município e por dia.

# %%
# Importa as libs e contecta com o json
import requests
import pandas as pd
from pandas.io.json import json_normalize

response = requests.get("https://brasil.io/api/dataset/covid19/caso/data?format=json")

# %%
# print(response.json())

for i in response.json()['results']:
    print(i)
# Out:
# {'city': 'Campina Grande', 'city_ibge_code': '2504009', 'confirmed': 1, 'confirmed_per_100k_inhabitants': 0.24406, 'date': '2020-03-27', 'death_rate': None, 'deaths': None, 'estimated_population_2019': 409731, 'is_last': True, 'place_type': 'city', 'state': 'PB'}
# {'city': 'Igaracy', 'city_ibge_code': '2502607', 'confirmed': 1, 'confirmed_per_100k_inhabitants': 16.34788, 'date': '2020-03-27', 'death_rate': None, 'deaths': None, 'estimated_population_2019': 6117, 'is_last': True, 'place_type': 'city', 'state': 'PB'}
# {'city': 'João Pessoa', 'city_ibge_code': '2507507', 'confirmed': 6, 'confirmed_per_100k_inhabitants': 0.74164, 'date': '2020-03-27', 'death_rate': None, 'deaths': 0, 'estimated_population_2019': 809015, 'is_last': True, 'place_type': 'city', 'state': 'PB'}
# ...
